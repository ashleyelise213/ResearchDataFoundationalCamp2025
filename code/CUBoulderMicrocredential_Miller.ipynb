# %% [markdown]
# # CU Boulder Microcredential Project
# ### Ashley Miller
# ### 1/19/24
#
# Data Import: https://www.cdc.gov/nchs/covid19/pulse/mental-health-care.htm

# %%
# Import pandas
import pandas as pd

# %%
# Import dataset
data = pd.read_csv("Mental_Health_Care_in_the_Last_4_Weeks.csv")
data
# Out:
#                                                Indicator              Group  \
# 0      Took Prescription Medication for Mental Health...  National Estimate
# 1      Took Prescription Medication for Mental Health...             By Age
# 2      Took Prescription Medication for Mental Health...             By Age
# 3      Took Prescription Medication for Mental Health...             By Age
# 4      Took Prescription Medication for Mental Health...             By Age
# ...                                                  ...                ...
# 10399  Needed Counseling or Therapy But Did Not Get I...           By State
# 10400  Needed Counseling or Therapy But Did Not Get I...           By State
# 10401  Needed Counseling or Therapy But Did Not Get I...           By State
# 10402  Needed Counseling or Therapy But Did Not Get I...           By State
# 10403  Needed Counseling or Therapy But Did Not Get I...           By State
#
#                State       Subgroup Phase  Time Period      Time Period Label  \
# 0      United States  United States     2           13  Aug 19 - Aug 31, 2020
# 1      United States  18 - 29 years     2           13  Aug 19 - Aug 31, 2020
# 2      United States  30 - 39 years     2           13  Aug 19 - Aug 31, 2020
# 3      United States  40 - 49 years     2           13  Aug 19 - Aug 31, 2020
# 4      United States  50 - 59 years     2           13  Aug 19 - Aug 31, 2020
# ...              ...            ...   ...          ...                    ...
# 10399       Virginia       Virginia   3.4           45   Apr 27 - May 9, 2022
# 10400     Washington     Washington   3.4           45   Apr 27 - May 9, 2022
# 10401  West Virginia  West Virginia   3.4           45   Apr 27 - May 9, 2022
# 10402      Wisconsin      Wisconsin   3.4           45   Apr 27 - May 9, 2022
# 10403        Wyoming        Wyoming   3.4           45   Apr 27 - May 9, 2022
#
#       Time Period Start Date Time Period End Date  Value  LowCI  HighCI  \
# 0                 08/19/2020           08/31/2020   19.4   19.0    19.8
# 1                 08/19/2020           08/31/2020   18.7   17.2    20.3
# 2                 08/19/2020           08/31/2020   18.3   17.3    19.2
# 3                 08/19/2020           08/31/2020   20.4   19.5    21.3
# 4                 08/19/2020           08/31/2020   21.2   20.2    22.2
# ...                      ...                  ...    ...    ...     ...
# 10399             04/27/2022           05/09/2022   10.1    7.1    13.8
# 10400             04/27/2022           05/09/2022   14.8   12.5    17.4
# 10401             04/27/2022           05/09/2022    9.8    6.6    13.8
# 10402             04/27/2022           05/09/2022   11.6    8.5    15.3
# 10403             04/27/2022           05/09/2022   11.5    8.6    15.1
#
#       Confidence Interval Quartile Range  Suppression Flag
# 0             19.0 - 19.8            NaN               NaN
# 1             17.2 - 20.3            NaN               NaN
# 2             17.3 - 19.2            NaN               NaN
# 3             19.5 - 21.3            NaN               NaN
# 4             20.2 - 22.2            NaN               NaN
# ...                   ...            ...               ...
# 10399          7.1 - 13.8       9.6-11.3               NaN
# 10400         12.5 - 17.4      13.0-20.8               NaN
# 10401          6.6 - 13.8       9.6-11.3               NaN
# 10402          8.5 - 15.3      11.4-12.9               NaN
# 10403          8.6 - 15.1      11.4-12.9               NaN
#
# [10404 rows x 15 columns]

# %%
# Check data type
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Check variable types
data.dtypes
# Out:
# Indicator                  object
# Group                      object
# State                      object
# Subgroup                   object
# Phase                      object
# Time Period                 int64
# Time Period Label          object
# Time Period Start Date     object
# Time Period End Date       object
# Value                     float64
# LowCI                     float64
# HighCI                    float64
# Confidence Interval        object
# Quartile Range             object
# Suppression Flag          float64
# dtype: object

# %%
data.groupby('Indicator').count()
# Out:
#                                                     Group  State  Subgroup  \
# Indicator
# Needed Counseling or Therapy But Did Not Get It...   2601   2601      2601
# Received Counseling or Therapy, Last 4 Weeks         2601   2601      2601
# Took Prescription Medication for Mental Health ...   2601   2601      2601
# Took Prescription Medication for Mental Health,...   2601   2601      2601
#
#                                                     Phase  Time Period  \
# Indicator
# Needed Counseling or Therapy But Did Not Get It...   2601         2601
# Received Counseling or Therapy, Last 4 Weeks         2601         2601
# Took Prescription Medication for Mental Health ...   2601         2601
# Took Prescription Medication for Mental Health,...   2601         2601
#
#                                                     Time Period Label  \
# Indicator
# Needed Counseling or Therapy But Did Not Get It...               2601
# Received Counseling or Therapy, Last 4 Weeks                     2601
# Took Prescription Medication for Mental Health ...               2601
# Took Prescription Medication for Mental Health,...               2601
#
#                                                     Time Period Start Date  \
# Indicator
# Needed Counseling or Therapy But Did Not Get It...                    2601
# Received Counseling or Therapy, Last 4 Weeks                          2601
# Took Prescription Medication for Mental Health ...                    2601
# Took Prescription Medication for Mental Health,...                    2601
#
#                                                     Time Period End Date  \
# Indicator
# Needed Counseling or Therapy But Did Not Get It...                  2601
# Received Counseling or Therapy, Last 4 Weeks                        2601
# Took Prescription Medication for Mental Health ...                  2601
# Took Prescription Medication for Mental Health,...                  2601
#
#                                                     Value  LowCI  HighCI  \
# Indicator
# Needed Counseling or Therapy But Did Not Get It...   2470   2470    2470
# Received Counseling or Therapy, Last 4 Weeks         2476   2476    2476
# Took Prescription Medication for Mental Health ...   2484   2484    2484
# Took Prescription Medication for Mental Health,...   2484   2484    2484
#
#                                                     Confidence Interval  \
# Indicator
# Needed Counseling or Therapy But Did Not Get It...                 2470
# Received Counseling or Therapy, Last 4 Weeks                       2476
# Took Prescription Medication for Mental Health ...                 2484
# Took Prescription Medication for Mental Health,...                 2484
#
#                                                     Quartile Range  \
# Indicator
# Needed Counseling or Therapy But Did Not Get It...            1683
# Received Counseling or Therapy, Last 4 Weeks                  1683
# Took Prescription Medication for Mental Health ...            1683
# Took Prescription Medication for Mental Health,...            1683
#
#                                                     Suppression Flag
# Indicator
# Needed Counseling or Therapy But Did Not Get It...                14
# Received Counseling or Therapy, Last 4 Weeks                       8
# Took Prescription Medication for Mental Health ...                 0
# Took Prescription Medication for Mental Health,...                 0

# %%
## Filter data

# Filter out NAs in the Value column
data_filtered = data.dropna(subset=['Value'])

# Filter Indicator to only include indicator of interest
data_filtered = data_filtered[data_filtered['Indicator'].isin(['Needed Counseling or Therapy But Did Not Get It, Last 4 Weeks'])]

# Drop unwanted columns
data_filtered = data_filtered[['Indicator', 'Group', 'State', 'Subgroup','Value', 'LowCI', 'HighCI']]

# %%
data_filtered
# Out:
#                                                Indicator              Group  \
# 216    Needed Counseling or Therapy But Did Not Get I...  National Estimate
# 217    Needed Counseling or Therapy But Did Not Get I...             By Age
# 218    Needed Counseling or Therapy But Did Not Get I...             By Age
# 219    Needed Counseling or Therapy But Did Not Get I...             By Age
# 220    Needed Counseling or Therapy But Did Not Get I...             By Age
# ...                                                  ...                ...
# 10399  Needed Counseling or Therapy But Did Not Get I...           By State
# 10400  Needed Counseling or Therapy But Did Not Get I...           By State
# 10401  Needed Counseling or Therapy But Did Not Get I...           By State
# 10402  Needed Counseling or Therapy But Did Not Get I...           By State
# 10403  Needed Counseling or Therapy But Did Not Get I...           By State
#
#                State       Subgroup  Value  LowCI  HighCI
# 216    United States  United States    9.2    8.8     9.6
# 217    United States  18 - 29 years   15.6   14.5    16.7
# 218    United States  30 - 39 years   12.9   11.9    13.9
# 219    United States  40 - 49 years   10.0    9.3    10.7
# 220    United States  50 - 59 years    7.7    6.9     8.5
# ...              ...            ...    ...    ...     ...
# 10399       Virginia       Virginia   10.1    7.1    13.8
# 10400     Washington     Washington   14.8   12.5    17.4
# 10401  West Virginia  West Virginia    9.8    6.6    13.8
# 10402      Wisconsin      Wisconsin   11.6    8.5    15.3
# 10403        Wyoming        Wyoming   11.5    8.6    15.1
#
# [2470 rows x 7 columns]

# %%
# Group by Subgroup and calculate mean value per subgroup. Convert to df
data_filtered_mean = data_filtered.groupby('Subgroup')['Value'].mean().reset_index()

# %%
data_filtered_mean
# Out:
#               Subgroup      Value
# 0        18 - 29 years  19.848485
# 1        30 - 39 years  15.566667
# 2        40 - 49 years  11.845455
# 3        50 - 59 years   9.148485
# 4        60 - 69 years   5.775758
# ..                 ...        ...
# 75       West Virginia  10.721212
# 76           Wisconsin   9.239394
# 77     With disability  24.083333
# 78  Without disability   8.727778
# 79             Wyoming  10.100000
#
# [80 rows x 2 columns]

# %%
# Sort by Value and display the top five subgroups with the highest mean value
top5 = data_filtered_mean.sort_values(by = 'Value', ascending = False)[0:5]

# %%
# Sort by Value and display the top five subgroups with the lowest mean value
bottom5 = data_filtered_mean.sort_values(by = 'Value', ascending = True)[0:5]

# %%
# Combine datasets to plot together
combined_data = pd.concat([top5, bottom5])
combined_data

type(combined_data)
combined_data.dtypes
# Out:
# Subgroup     object
# Value       float64
# dtype: object

# %%
# Import libraries for plotting
import matplotlib.pyplot as plt

# %%
# Plot mean values of highest and lowest subgroups
combined_data.plot(
    kind = 'bar', # horizontal bar chart
    x = 'Subgroup',
    y = 'Value',
    color=['#1f77b4'],  # Custom color
    title = 'Subgroups of the five highest and lowest mean value'
)

plt.xlabel('Subgroup')
plt.ylabel('Mean Value (%)')
plt.show()

# %% [markdown]
# ### Conclusion
#
# The five subgroups who exhibited the **highest** mean value and answered "Needed Counseling or Therapy But Did Not Get It, Last 4 Weeks" were:
# 1. Transgender
# 2. Bisexual
# 3. Experienced symptoms of anxiety/depression in past 4 weeks
# 4. With disability
# 5. Gay or lesbian
#
# The five subgroups who exhibited the **lowest** mean value and answered "Needed Counseling or Therapy But Did Not Get It, Last 4 Weeks" were:
# 1. 70-79 years
# 2. 80 years and above
# 3. Did not experience symptoms of anxiety/depression in past 4 weeks
# 4. 60-69 years
# 5. Non-Hispanic Asian, single race
